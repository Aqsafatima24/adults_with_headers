# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('ToyotaCorolla - MLR.csv')  # Assuming CSV file is given
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
# Summary statistics
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %% [markdown]
# ### Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pairplot to visualize relationships
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
price=pd.DataFrame(df["Price"])
price
# Out:
#       Price
# 0     13500
# 1     13750
# 2     13950
# 3     14950
# 4     13750
# ...     ...
# 1431   7500
# 1432  10845
# 1433   8500
# 1434   7250
# 1435   6950
#
# [1436 rows x 1 columns]

# %%
age=pd.DataFrame(df["Age_08_04"])
age
# Out:
#       Age_08_04
# 0            23
# 1            23
# 2            24
# 3            26
# 4            30
# ...         ...
# 1431         69
# 1432         72
# 1433         71
# 1434         70
# 1435         76
#
# [1436 rows x 1 columns]

# %%
km=pd.DataFrame(df["KM"])
km
# Out:
#          KM
# 0     46986
# 1     72937
# 2     41711
# 3     48000
# 4     38500
# ...     ...
# 1431  20544
# 1432  19000
# 1433  17016
# 1434  16916
# 1435      1
#
# [1436 rows x 1 columns]

# %%
hp=pd.DataFrame(df["HP"])
hp
# Out:
#        HP
# 0      90
# 1      90
# 2      90
# 3      90
# 4      90
# ...   ...
# 1431   86
# 1432   86
# 1433   86
# 1434   86
# 1435  110
#
# [1436 rows x 1 columns]

# %%
auto=pd.DataFrame(df["Automatic"])
auto
# Out:
#       Automatic
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1431          0
# 1432          0
# 1433          0
# 1434          0
# 1435          0
#
# [1436 rows x 1 columns]

# %%
cyvolume=pd.DataFrame(df["cc"])
cyvolume
# Out:
#         cc
# 0     2000
# 1     2000
# 2     2000
# 3     2000
# 4     2000
# ...    ...
# 1431  1300
# 1432  1300
# 1433  1300
# 1434  1300
# 1435  1600
#
# [1436 rows x 1 columns]

# %%
doors=pd.DataFrame(df["Doors"])
doors
# Out:
#       Doors
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 1431      3
# 1432      3
# 1433      3
# 1434      3
# 1435      5
#
# [1436 rows x 1 columns]

# %%
cylinder=pd.DataFrame(df["Cylinders"])
cylinder
# Out:
#       Cylinders
# 0             4
# 1             4
# 2             4
# 3             4
# 4             4
# ...         ...
# 1431          4
# 1432          4
# 1433          4
# 1434          4
# 1435          4
#
# [1436 rows x 1 columns]

# %%
gear=pd.DataFrame(df["Gears"])
gear
# Out:
#       Gears
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...     ...
# 1431      5
# 1432      5
# 1433      5
# 1434      5
# 1435      5
#
# [1436 rows x 1 columns]

# %%
wt=pd.DataFrame(df["Weight"])
wt
# Out:
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 1 columns]

# %%
correlation_matrix=df[["Price","Age_08_04","KM","HP","Automatic","cc","Doors","Gears","Weight"]].corr()
sns.heatmap(correlation_matrix,annot=True,cmap='PuBu')
plt.title("Correlation of each and every Variable")
plt.show()

# %% [markdown]
# With this observation, we can conclude the following:
#
# 1. **Price** and **Age** have a strong negative correlation.
# 2. **Price** and **Kilometers (KM)** have a moderate negative correlation.
# 3. **Price** and **Weight** have a moderate positive correlation.
# 4. **Price** and **Horsepower (HP)** have a weak positive correlation.
# 5. **Age** and **Weight** also have a weak negative correlation.
#
# The rest of the variables seem to have little to no noticeable relationship with **Price**.

# %%
print(df.columns)  # This will print all the column names in the DataFrame
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
relations=df[["HP","Age_08_04","KM","Weight"]]
sns.boxplot(relations , palette="coolwarm")
plt.xlabel("box plot for(Hp,Age_08_04,km,Weight)")
plt.ylabel("values")
plt.show()

# %%
sns.countplot(x='Fuel_Type', data=df)
plt.show()

# %% [markdown]
# ### pre-process

# %%
# One-hot encoding for 'FuelType'
df = pd.get_dummies(df, columns=['Fuel_Type'], drop_first=True)
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
# Normalize or standardize numerical variables if needed
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['Age_08_04', 'KM', 'HP', 'cc', 'Weight']] = scaler.fit_transform(df[['Age_08_04', 'KM', 'HP', 'cc', 'Weight']])
df
# Out:
#       Price  Age_08_04        KM        HP  Automatic        cc  Doors  \
# 0     13500  -1.771966 -0.574695 -0.768042          0  0.997419      3
# 1     13750  -1.771966  0.117454 -0.768042          0  0.997419      3
# 2     13950  -1.718184 -0.715386 -0.768042          0  0.997419      3
# 3     14950  -1.610620 -0.547650 -0.768042          0  0.997419      3
# 4     13750  -1.395491 -0.801028 -0.768042          0  0.997419      3
# ...     ...        ...       ...       ...        ...       ...    ...
# 1431   7500   0.702015 -1.279939 -1.035138          0 -0.652594      3
# 1432  10845   0.863362 -1.321120 -1.035138          0 -0.652594      3
# 1433   8500   0.809579 -1.374036 -1.035138          0 -0.652594      3
# 1434   7250   0.755797 -1.376703 -1.035138          0 -0.652594      3
# 1435   6950   1.078490 -1.827849  0.567440          0  0.054555      5
#
#       Cylinders  Gears    Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %% [markdown]
# ### Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
from sklearn.model_selection import train_test_split

# Define independent variables (X) and dependent variable (y)
X = df.drop('Price', axis=1)  # Independent variables
y = df['Price']  # Dependent variable

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=48)

# %% [markdown]
# ### MODELS

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Initialize and train the model
model1 = LinearRegression()
model1.fit(X_train, y_train)

# Predict on test set
y_pred1 = model1.predict(X_test)

# Model evaluation
print("R-squared:", r2_score(y_test, y_pred1).round(3))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred1).round(3)))
# Out:
# R-squared: 0.829
# RMSE: 1534.0207052057674

# %%
X_train2 = X_train.drop(['HP'], axis=1)
X_test2 = X_test.drop(['HP'], axis=1)

# Train model
model2 = LinearRegression()
model2.fit(X_train2, y_train)

# Predict and evaluate
y_pred2 = model2.predict(X_test2)
print("R-squared:", r2_score(y_test, y_pred2).round(3))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred2).round(3)))
# Out:
# R-squared: 0.818
# RMSE: 1584.850424488065

# %%
X_train3 = X_train[['Age_08_04', 'KM', 'cc']]
X_test3 = X_test[['Age_08_04', 'KM', 'cc']]

# Train model
model3 = LinearRegression()
model3.fit(X_train3, y_train)

# Predict and evaluate
y_pred3 = model3.predict(X_test3)
print("R-squared:", r2_score(y_test, y_pred3).round(3))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred3).round(3)))
# Out:
# R-squared: 0.766
# RMSE: 1796.525433997526

# %% [markdown]
# the error have decreased and even the model performance ,but we can safely say that after performing feauture engineering our model have given better error,even though our rsquare is 76%,it is an average model but we can say that is a better model than other previous models.

# %% [markdown]
# ### Evaluation

# %%
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test2)
y_pred3 = model3.predict(X_test3)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {round(mae, 3)}, MSE: {round(mse, 3)}, R²: {round(r2, 3)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 6
#       3 y_pred3 = model3.predict(X_test3)
#       4 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# ----> 6 mae = mean_absolute_error(y_test, y_pred)
#       7 mse = mean_squared_error(y_test, y_pred)
#       8 r2 = r2_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# ### Lasso regression

# %%
from sklearn.linear_model import Lasso

# Train Lasso regression model
lasso = Lasso(alpha=0.1)  # Alpha is the regularization strength
lasso.fit(X_train, y_train)

# Predict and evaluate
y_pred_lasso = lasso.predict(X_test)
print("Lasso R-squared:", r2_score(y_test, y_pred_lasso))
print("Lasso RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_lasso)))

# %% [markdown]
# ### Ridge regression

# %%
from sklearn.linear_model import Ridge

# Train Ridge regression model
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

# Predict and evaluate
y_pred_ridge = ridge.predict(X_test)
print("Ridge R-squared:", r2_score(y_test, y_pred_ridge))
print("Ridge RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_ridge)))

# %% [markdown]
# ### 1. What is Normalization & Standardization and how is it helpful?
#
# **Normalization** scales data to a range, typically between 0 and 1. It’s useful when the data has varying scales and you want all features to contribute equally in machine learning algorithms.
#
# **Standardization** transforms data to have a mean of 0 and a standard deviation of 1. It’s helpful when the data is normally distributed or when the model assumes a normal distribution.

# %% [markdown]
# ### 2.What techniques can be used to address multicollinearity in multiple linear regression?
#
# Techniques to address multicollinearity in multiple linear regression:
# 1. Remove highly correlated variables: If two variables are highly correlated, consider removing one.
# 2. Combine variables: Create a new variable that combines the two correlated variables (e.g., average or sum).
# 3. Principal Component Analysis (PCA): Reduces dimensionality by creating uncorrelated components from the original variables.
# 4. Regularization (Lasso or Ridge): These techniques penalize large coefficients, helping to reduce the impact of multicollinearity.
# 5. Variance Inflation Factor (VIF): Calculate VIF for each variable and remove those with a high VIF, indicating multicollinearity.
